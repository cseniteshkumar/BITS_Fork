# %%
'''
Exercise 1: Bank Account (Basic)
Problem:
Create a class BankAccount with private attributes:

account_number

balance

Provide methods:

deposit(amount)

withdraw(amount)

get_balance()
'''

# %%
'''
Exercise 2: Machine Control Panel
Problem:
Create a class Machine with private attributes:

__status (Running/Stopped)

__temperature

Provide methods to:

Start/stop the machine.

Set temperature (only if the machine is running).

Get current status.
'''

# %%
'''
Exercise 3: Robot Battery Management
Problem:
Create a class Robot with private attributes:

__battery_level (0-100%)

__is_active (True/False)

Methods:

charge(amount) (cannot exceed 100)

work(hours) (reduces battery)

get_battery_status()
'''

# %%
'''
Exercise 4: Factory Sensor Data
Problem:
Create a class Sensor with private attributes:

__sensor_id

__value (0-100)

Methods:

update_value(value)

get_value()

is_safe() (returns True if value < 70)
'''

# %%
'''
Exercise 5: Employee Salary Management

Problem:
Create a class Employee with private attributes:

__name

__salary

Methods:

increase_salary(amount) (only positive values)

get_salary()
'''

# %%
## Inheritance Exercise

# %%
'''
EXERCISE 0:
Create a parent class Person with attributes name and age.
Create a child class Student that adds roll_no and a method show_student_details().
'''

# %%
'''
Exercise 1: Multilevel Inheritance – Robot Control
Problem:
Create a multilevel class structure:

Robot: Base class with name and show_name() method.

AssemblyRobot (inherits from Robot): Adds task and show_task() method.

SmartAssemblyRobot (inherits from AssemblyRobot): Adds efficiency and a show_details() method that prints all details.
'''

# %%
'''
Exercise 2: Hierarchical Inheritance – Sensors
Problem:
Create a base class Sensor with sensor_id.
Derive TemperatureSensor, PressureSensor, and VibrationSensor, each with their specific method read_value() that prints mock sensor data.

'''

# %%
'''
Exercise 3: Multilevel Inheritance – Machine Status
Problem:

Create Machine (base class) with machine_name.

Create ProductionMachine (inherits Machine) with units_produced.

Create SmartMachine (inherits ProductionMachine) with defect_rate and show_status() that prints name, units, and defect rate.
'''

# %%
'''
Exercise 4: Hierarchical Inheritance – Workers
Problem:
Create a base class Worker with name.
Derive Operator, Supervisor, and Engineer.
Each class should have its own method work_role() that prints a unique role.
'''

# %%
'''
Exercise 5: Combined Use of Multilevel and Hierarchical Inheritance – Factory
Problem:

Create Factory (base class) with factory_name.

Create Department (inherits Factory) with department_name.

From Department, create AssemblyDept and QualityDept, each with a method to print department-specific tasks.

'''
