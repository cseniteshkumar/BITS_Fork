# %%
'''
  Exercise 1: Create and write to a file.
  Write py program Create file named "machines.txt" amd write below lines
  Machine A - Good
  Machine B - Better
  Machine C - Fail
'''

# %%
'''
  Exercise 2: Read a File and Display Content.
  Write py program that reads file "machines.txt" and displays each line on the screen.
'''

# %%
'''
  Exercise 3:  Count Number of Lines
  Write py program that open "machines.txt" and print total number of lines in the file.
'''

# %%
'''
  Exercise 4: Search for specific word
  Write py program to search for word "Fail" in file "machines.txt" and print alll lines that contain that word.
'''

# %%
'''
  Exercise 5: Append New Machine status.
  Write py program to append below line in "machines.txt" file.

  Machine D - Running
'''
