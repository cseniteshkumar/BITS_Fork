# %%
'''
MODULARITY
1. WHAT? -- Breaking down program into smaller, reusable parts
2. BENEFITS ? --
 A. Improve code readability and maintain
 B. Easier to debug and test
 C. Reusable

'''
# Out:
# hi

# %%
## How to create function and use it ..

# %%
def greet(name):
  return f'Hello, {name}'

# %%
greet('BITS Class')
# Out:
# 'Hello, BITS Class'

# %%
greet('Aakash')
# Out:
# 'Hello, Aakash'

# %%
def calculate_area(length, width):
  return length*width

# %%
calculate_area(5,3)
# Out:
# 15

# %%
## Module:: File containing python code (Functions, classes, variables) that can be imported and used in other python programs.

# %%
! touch import_experiment.py

# %%
from import_experiment import create_data

# %%
??create_data

# %%
names = ['Aakash','Amit','Ramesh']
marks = [70,80,90]
df = create_data(names, marks)
display(df)
# Out:
#      Name  Marks
# 0  Aakash     70
# 1    Amit     80
# 2  Ramesh     90

# %%
! touch string_utils.py

# %%
from string_utils import reverse_string

# %%
reverse_string('AAKASH')
# Out:
# 'HSAKAA'

# %%
reverse_string('OM')
# Out:
# 'MO'

# %%
reverse_string('MOM')
# Out:
# 'MOM'

# %%
## Package -- Directory containing multiple modules and special __init__.py file

# %%
# !mkdir utilities

# %%
# !cp import_experiment.py string_utils.py utilities/

# %%
# !touch utilities/__init__.py

# %%
from utilities import string_utils

# %%
string_utils.reverse_string('AAKASH')
# Out:
# 'HSAKAA'
